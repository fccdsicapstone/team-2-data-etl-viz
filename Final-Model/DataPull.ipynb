# %%
import pandas as pd

query = """
SELECT * FROM `fccdsicapstone-218522.broadband.fcc_acs_with_geo_and_props_2014` 
"""

table = pd.read_gbq(query, project_id='fccdsicapstone-218522', dialect='standard')
table
# Out:
#        block_group_code state_county_code    state           county  \
# 0          510190501005              None     None             None
# 1          360530301011              None     None             None
# 2          360530301012              None     None             None
# 3          040190041211              None     None             None
# 4          360530301033              None     None             None
# 5          360650247004              None     None             None
# 6          360530303003              None     None             None
# 7          360530304011              None     None             None
# 8          040190029061              None     None             None
# 9          360530304012              None     None             None
# 10         040190053001              None     None             None
# 11         060371370001              None     None             None
# 12         360530306001              None     None             None
# ...

# %%
import pandas as pd

query = """
SELECT * FROM `fccdsicapstone-218522.broadband.fcc_acs_with_geo_and_props_2015` 
"""

table2 = pd.read_gbq(query, project_id='fccdsicapstone-218522', dialect='standard')
table2
# Out:
#        block_group_code state_county_code          state             county  \
# 0          010010207001             01001        Alabama     Autauga County
# 1          010510310002             01051        Alabama      Elmore County
# 2          010510313001             01051        Alabama      Elmore County
# 3          010510310001             01051        Alabama      Elmore County
# 4          011010055033             01101        Alabama  Montgomery County
# 5          011010003001             01101        Alabama  Montgomery County
# 6          040050009002             04005        Arizona    Coconino County
# 7          040050002001             04005        Arizona    Coconino County
# 8          040050013011             04005        Arizona    Coconino County
# 9          040050012001             04005        Arizona    Coconino County
# 10         040139413004             04013        Arizona    Maricopa County
# ...

# %%
import pandas as pd

query = """
SELECT * FROM `fccdsicapstone-218522.broadband.fcc_acs_with_geo_and_props_2016` 
"""

table3 = pd.read_gbq(query, project_id='fccdsicapstone-218522', dialect='standard')

# %%
table.to_csv("full_2014_data.csv")
table2.to_csv("full_2015_data.csv")
table3.to_csv("full_2016_data.csv")
print("Done")
# Out:
# Done
